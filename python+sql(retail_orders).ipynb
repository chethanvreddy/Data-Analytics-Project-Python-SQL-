# %%
# !pip install kaggle

# %%
# !pip install pandas

# %%
import kaggle
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/200k [00:00<?, ?B/s]
# 100%|##########| 200k/200k [00:00<00:00, 252kB/s]
# 100%|##########| 200k/200k [00:00<00:00, 252kB/s]

# %%
import zipfile
zip_ref=zipfile.ZipFile('orders.csv.zip')
zip_ref.extractall()
zip_ref.close()

# %%
import pandas as pd
df=pd.read_csv('orders.csv', na_values=['Not Available','unknown'])
df_columns=df.columns
df.columns=df_columns.str.lower()
df.columns=df.columns.str.replace(' ','_')
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
df['dis']=df['list_price']*df['discount_percent']*.01
df['sales']=df['list_price']-df['dis']
df['profit']=df['sales']-df['cost_price']

# %%
df.drop(columns=['list_price','cost_price','discount_percent'],inplace=True)
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
#load the data into the sql server using replace option
# !pip install sqlalchemy
# Out:
# ...
#   Using cached SQLAlchemy-2.0.30-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached greenlet-3.0.3-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB 217.9 kB/s eta 0:00:10
#     --------------------------------------- 0.1/2.1 MB 375.8 kB/s eta 0:00:06
#    -- ------------------------------------- 0.1/2.1 MB 804.6 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.3/2.1 MB 1.3 MB/s eta 0:00:02
#    ------- -------------------------------- 0.4/2.1 MB 1.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.5/2.1 MB 1.8 MB/s eta 0:00:01
#    ------------ --------------------------- 0.7/2.1 MB 2.0 MB/s eta 0:00:01
# ...

# %%
# !pip install pyodbc
# Out:
# ...
#    ---------------------------------------- 0.0/69.3 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/69.3 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/69.3 kB ? eta -:--:--
#    ----------------- ---------------------- 30.7/69.3 kB 220.2 kB/s eta 0:00:01
#    ---------------------------------------- 69.3/69.3 kB 378.3 kB/s eta 0:00:00
# ...

# %%
#load the data into sql server using replae option
import sqlalchemy as sal
import pyodbc
engine = sal.create_engine(r'mssql+pyodbc://Admin\SQLEXPRESS/master?driver=ODBC+DRIVER+17+FOR+SQL+SERVER')
conn=engine.connect()

# %%
#load the data into sql server using append option
df.to_sql('df_orders', con=conn, index=False, if_exists= 'append')
# Out:
# 38
